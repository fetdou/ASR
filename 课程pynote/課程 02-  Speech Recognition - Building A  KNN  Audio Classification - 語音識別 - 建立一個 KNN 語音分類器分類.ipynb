# %% [markdown]
# <h1 align='center' style='color:purple'> Speech Recognition 語音識別 - 課程 02-  Speech Recognition - Building A  KNN  Audio Classification - 語音識別 - 建立一個 KNN 語音分類器分類 - Python Tutorial</h1>

# %% [raw]
# '''
#
# 人工智慧-深度學習
#
# A.I Tutorials
# Deep Learning 教程
#
# '''
#
#     04 - 課程    - Speech Recognition 語音識別
#
#          課程 02 - Speech Recognition
#                             - Building A  KNN  Audio Classification
#
#
#          課程 02 - 語音識別  - 語音識別 簡介
#
#
#                    程式範例 - 建立一個 KNN 語音分類器
#
# '''  教程簡介 '''
# '''  語音識別 '''
#
# '''

# %% [raw]
# '''
#
# >> 語音識別 流程
#     >> speech recognition pipeline
#
# '''

# %% [markdown]
# <img src="https://i1.wp.com/www.simplifiedpython.net/wp-content/uploads/2018/07/speech-recognition-python-1.png?w=682&ssl=1" width="100%">

# %% [markdown]
# <img src="https://www.mathworks.com/help/examples/audio_wavelet/win64/xxSpeakerID01.png" width="100%">

# %% [markdown]
# <img src="https://miro.medium.com/max/2000/0*SukgVDWR-kBWrPqf." width="100%">

# %% [markdown]
# <img src="http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424181/K-Nearest_ledzue.png" width="100%">

# %% [markdown]
# <img src="http://res.cloudinary.com/dyd911kmh/image/upload/f_auto,q_auto:best/v1531424125/KNN_final1_ibdm8a.png" width="100%">

# %% [raw]
# '''
#
# >> 語音識別 流程
#     >> speech recognition pipeline
#
#
# '''

# %% [raw]
# '''
#
#     >> 音頻信號 -Audio Signal
#
# '''

# %% [markdown]
# <img src="https://s3-ap-south-1.amazonaws.com/av-blog-media/wp-content/uploads/2019/07/originofsound.gif" width="100%">

# %% [markdown]
# <img src="https://devblogs.nvidia.com/wp-content/uploads/2019/03/pasted-image-0-19-768x287.png" width="100%">

# %% [raw]
# '''
#
# >> 頻譜圖 - spectrogram
# >> 每20毫秒的音頻塊上重複這個過程
#     >> 得到一個頻譜圖
#     >> 每個列從左到右是一個20ms的塊
#
#
#     >> 音頻數據中 - 看到 音符和其他音高模式
#     >>  musical notes and other pitch patterns in audio data
#
# '''

# %% [markdown]
# <img src="https://miro.medium.com/max/2421/1*bhd7B-s-Qnds3HGV6LOo8A.png" width="100%">

# %% [raw]
# '''
#
# >> 資料準備
#
#     >> 你我互動學習園地
#         >> https://interactiveuandmetutorials.weebly.com/
#
#     >> Python 程式語言 設計
#        >> https://pythonprogrammingtutorials.weebly.com/
#
#
#
# >> 檔案路徑/
#     ├── 課程 02-  Speech Recognition - Building A  KNN  Audio Classification - 語音識別 - 建立一個 KNN 語音分類器分類
#     ├────── train/
#     ├        ├── fcmc0-a1-t.wav
#     ├        ├── fcmc0-b1-tr.wav
#     ├        ├── ............wav
#     ├
#     ├────── test/
#     ├        ├── farw0-b1-t.wav
#     ├
#     ├
#     ├────── audio_files/
#     ├          ├── harvard.wav
#     ├          ├── jackhammer.wav
#     ├
#     ├
#     ├────── sounds/
#               ├── 10.wav
#               ├── 78.wav
#
#     '''

# %%
ddir
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2 的目錄
#
# 2019/09/23  下午 05:21    <DIR>          .
# 2019/09/23  下午 05:21    <DIR>          ..
# 2019/09/23  下午 03:39    <DIR>          .ipynb_checkpoints
# 2019/09/23  下午 03:59    <DIR>          audio_files
# 2019/09/23  下午 03:57    <DIR>          test
# 2019/09/23  下午 03:58    <DIR>          train
#                0 個檔案               0 位元組
#                6 個目錄  43,401,539,584 位元組可用

# %%
cd audio_files
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\audio_files

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\audio_files 的目錄
#
# 2019/09/23  下午 03:59    <DIR>          .
# 2019/09/23  下午 03:59    <DIR>          ..
# 2019/09/16  上午 11:45            23,712 eng.mp3
# 2018/05/02  下午 09:32         3,249,924 harvard.wav
# 2019/09/19  下午 02:47            16,509 hello4.mp3
# 2018/05/02  下午 09:32           600,204 jackhammer.wav
#                4 個檔案       3,890,349 位元組
#                2 個目錄  43,401,646,080 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2

# %%
cd train
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\train

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\train 的目錄
#
# 2019/09/23  下午 03:58    <DIR>          .
# 2019/09/23  下午 03:58    <DIR>          ..
# 2018/09/12  下午 11:09            13,872 fcmc0-a1-t.wav
# 2018/09/12  下午 11:09            15,408 fcmc0-b1-t.wav
# 2018/09/12  下午 11:09            18,384 fews0-a1-t.wav
# 2018/09/12  下午 11:09            17,808 fews0-b1-t.wav
# 2018/09/12  下午 11:09            17,424 fmb0-a1-t.wav
# 2018/09/12  下午 11:09            16,464 fmb0-b1-t.wav
# 2018/09/12  下午 11:09            17,136 fmbd0-a1-t.wav
# 2018/09/12  下午 11:09            22,416 fmbd0-b1-t.wav
# 2018/09/12  下午 11:09            16,944 fme0-a1-t.wav
# 2018/09/12  下午 11:09            17,520 fme0-b1-t.wav
# 2018/09/12  下午 11:09            17,904 frw0-a1-t.wav
# 2018/09/12  下午 11:09            16,752 frw0-b1-t.wav
# 2018/09/12  下午 11:09            17,904 mjp0-a1-t.wav
# 2018/09/12  下午 11:09            15,216 mjp0-b1-t.wav
# ...

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2 的目錄
#
# 2019/09/23  下午 05:21    <DIR>          .
# 2019/09/23  下午 05:21    <DIR>          ..
# 2019/09/23  下午 03:39    <DIR>          .ipynb_checkpoints
# 2019/09/23  下午 03:59    <DIR>          audio_files
# 2019/09/23  下午 04:06           661,771 SR02youtubefrontpage.png
# 2019/09/23  下午 04:05           468,943 SR02youtubefrontpage.pptx
# 2019/09/23  下午 03:57    <DIR>          test
# 2019/09/23  下午 03:58    <DIR>          train
# 2019/09/23  下午 05:21            75,540 課程 02-  Speech Recognition - Building A  KNN  Audio Classification - 語音識別 - 建立一個 KNN 語音分類器分類.ipynb
#                3 個檔案       1,206,254 位元組
#                6 個目錄  43,401,240,576 位元組可用

# %%
cd test
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\test

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2\test 的目錄
#
# 2019/09/23  下午 03:57    <DIR>          .
# 2019/09/23  下午 03:57    <DIR>          ..
# 2018/09/12  下午 11:09            11,472 farw0-b1-t.wav
#                1 個檔案          11,472 位元組
#                2 個目錄  43,400,052,736 位元組可用

# %%
cd ..
# Out:
# C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2

# %% [raw]
# '''
#
# >> 語音識別 - Speech Recognition
#     >> 語音識別 - 函式庫
#     >> https://github.com/Uberi/speech_recognition#readme
#     >> 導入 相關 函式庫
#        >> import relative Lib
#
#        >> pip install SpeechRecognition
#
# '''

# %%
# %matplotlib inline

# %%
import speech_recognition as sr
print(sr.__version__)
# Out:
# 3.8.1

# %%
r = sr.Recognizer()

# %% [raw]
# '''
#
# >> record()
#     >> 音頻文件中獲取數據
#
# recognize_bing()        : Microsoft Bing Speech
# recognize_google()      : Google Web Speech API
# recognize_google_cloud(): Google Cloud Speech - requires installation of the google-cloud-speech package
# recognize_houndify()    : Houndify by SoundHound
# recognize_ibm()         : IBM Speech to Text
# recognize_sphinx()      : CMU Sphinx - requires installing PocketSphinx
# recognize_wit()         : Wit.ai
#
#     >> Recognizer API主要用於 識別語音
#         >> 每個API都有多個設置和功能來識別音頻源的語音
#     >> recognition_sphinx()
#         >> 可以與CMU Sphinx引擎offline 工作
#         >> 其他六個需要連接online 到 Internet
#
#
# '''

# %% [raw]
# '''
#
# >> 支持的文件類型。
#     >> peechRecognition目前支持以下文件類型。
#
#         >> WAV：必須是PCM / LPCM格式。
#         >> AIFF
#         >> AIFF-C
#         >> FLAC：必須是原始的FLAC格式
#             >> OGG-FLAC格式不可用
#
#
# '''

# %%
ddir
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2 的目錄
#
# 2019/09/23  下午 05:21    <DIR>          .
# 2019/09/23  下午 05:21    <DIR>          ..
# 2019/09/23  下午 03:39    <DIR>          .ipynb_checkpoints
# 2019/09/23  下午 03:59    <DIR>          audio_files
# 2019/09/23  下午 03:57    <DIR>          test
# 2019/09/23  下午 03:58    <DIR>          train
#                0 個檔案               0 位元組
#                6 個目錄  43,398,692,864 位元組可用

# %% [markdown]
# # audio_fileseng.mp3

# %% [raw]
# '''
#
# >> Playsound - 僅包含一件事-函數（稱為）playsound
# >> playsound - contains only one thing - the function (also named) playsound
#     >> pip install playsound
#     >> https://github.com/TaylorSMarks/playsound
#
# '''

# %%
import playsound

# %%
from playsound import playsound
playsound('audio_files\eng.mp3')

# %%
import IPython.display as ipd

# %%
import librosa
y1, sr1 = librosa.load('audio_files\eng.mp3')
ipd.Audio(y1, rate=sr1)
# Out:
# ---------------------------------------------------------------------------
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-25-8920b151393d> in <module>()
#       1 import librosa
# ----> 2 y1, sr1 = librosa.load('audio_files\eng.mp3')
#       3 ipd.Audio(y1, rate=sr1)
#
# ~\Anaconda36\lib\site-packages\librosa\core\audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     110
#     111     y = []
# --> 112     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     113         sr_native = input_file.samplerate
#     114         n_channels = input_file.channels
#
# ~\Anaconda36\lib\site-packages\audioread\__init__.py in audio_open(path)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %% [markdown]
# # audio_files\harvard.wav

# %%
import IPython.display as ipd

# %%
import librosa
y1, sr1 = librosa.load('audio_files\harvard.wav')
ipd.Audio(y1, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline

# %%
import speech_recognition as sr
print(sr.__version__)
# Out:
# 3.8.1

# %%
r = sr.Recognizer()

# %%
harvard = sr.AudioFile('audio_files\harvard.wav')
with harvard as source:
   audio = r.record(source)

# %% [raw]
# '''
#
# >> record()函數
#     >> 將整個文件數據讀入AudioData實例
#         >> 這可以通過檢查音頻類型
#
# '''

# %%
type(audio)
# Out:
# speech_recognition.AudioData

# %%
r.recognize_google(audio)
# Out:
# 'the stale smell of old beer lingers it takes heat to bring out the odor a cold dip restores health and zest a salt pickle taste fine with ham tacos al Pastore are my favorite a zestful food is be hot cross bun'

# %% [raw]
# '''
#
# >> 偏移和持續時間捕獲音頻剪輯
#
# >>> with harvard as source:
# ... audio = r.record(source, duration=4)
# ...
# >>> sr.recognize_google(audio)
# 'the stale smell of old beer lingers'
#
# >> 前四秒音頻將保存在audio1中，後四秒鐘音頻將保存在audio2中
#
# >>> with harvard as source:
# ... audio1 = sr.record(source, duration=4)
# ... audio2 = sr.record(source, duration=4)
# ...
# >>> sr.recognize_google(audio1)
# 'the stale smell of old beer lingers'
# >>> sr.recognize_google(audio2)
# 'it takes heat to bring out the odor a cold dip'
#
# >> 偏移設置為4秒，並記錄持續時間3秒
#
# >>> with harvard as source:
# ... audio = sr.record(source, offset=4, duration=3)
# ...
# >>> recognizer.recognize_google(audio)
# 'it takes heat to bring out the odor'
#
# >> 事先知道文件的語音結構時
#     >> 偏移和持續時間關鍵字參數對於分割音頻文件非常有用
#     >> 但不准確的使用會導致轉錄不良
#
# >>> with harvard as source:
# ... audio = r.record(source, offset=4.7, duration=2.8)
# ...
# >>> recognizer.recognize_google(audio)
#
#
# >> 上面的程序記錄從4.7秒開始
#     >> 因此短語“it t”中的短語“它需要加熱來帶出氣味”並沒有記錄
#         >> 並且API只獲得輸入“akes heat”並匹配結果“Mesquite”
#         >> 類似地，API僅在錄音結束時
#             >> 為“冷浸恢復健康和熱情”這一短語捕獲了“a co”
#             >> 並且與“Aiko”不匹配
# '''

# %%
with harvard as source:
    audio = r.record(source, duration=4)

r.recognize_google(audio)
# Out:
# 'the stale smell of old beer lingers'

# %%
with harvard as source:
    audio1 = r.record(source, duration=4)
    audio2 = r.record(source, duration=4)

# %%
r.recognize_google(audio1)
# Out:
# 'the stale smell of old beer lingers'

# %%
r.recognize_google(audio2)
# Out:
# 'it takes heat to bring out the odor a cold dip'

# %%
import speech_recognition as sr

# %%
r = sr.Recognizer()

# %%
harvard = sr.AudioFile('audio_files\harvard.wav')
with harvard as source:
   audio = r.record(source)

# %%
with harvard as source:
    audio = r.record(source, offset=4, duration=3)

# %%
r.recognize_google(audio)
# Out:
# 'it takes heat to bring out the odor'

# %% [raw]
# '''
#
# >> 4.7秒 - 開始錄製 recording
#     >> 錯過 " it t " 部分
#     >> 即“it takes heat to bring out the odor ”這一短語 phrase 的開頭
#     >> 因此API只能獲得“akes heat ”，它與“Mesquite”matched
#
#     >> 同樣地
#         >> 錄音結束時
#         >> 捕捉到了“a co ”
#         >> 這是第三個短語 " cold dip restores health and zest. " 的開始
#         >> 這與API的 " Aiko " 相匹配- matched
#
# '''

# %%
with harvard as source:
    audio = r.record(source, offset=4.7, duration=2.8)

r.recognize_google(audio)
# Out:
# 'Mesquite to bring out the odor Aiko'

# %% [raw]
# '''
#
# >> 噪聲對語音識別的影響
#     >> The Effect of Noise on Speech Recognition
#     >> 噪音是生活中的事實
#     >> 所有錄音都有一定程度的噪音
#     >> 未處理的噪音可能會破壞語音識別應用的準確性
#
# '''

# %% [raw]
# '''
#
# >> LibROSA - 是用於 音樂和音頻 分析的 python 軟件包
# >> LibROSA - is a python package for music and audio analysis
#     >> pip install librosa
#     >> https://librosa.github.io/librosa/
#
# '''

# %% [markdown]
# # audio_files\jackhammer.wav

# %%
import IPython.display as ipd

# %%
import librosa
y1, sr1 = librosa.load('audio_files\jackhammer.wav')
ipd.Audio(y1, rate=sr1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
jackhammer = sr.AudioFile('audio_files\jackhammer.wav')
with jackhammer as source:
   audio = r.record(source)

# %%
type(audio)
# Out:
# speech_recognition.AudioData

# %%
r.recognize_google(audio)
# Out:
# 'the snail smell of old beer drinkers'

# %% [raw]
# '''
#
# >> 噪聲對語音識別的影響
#     >> 現實世界中存在噪聲，並且所有錄音都有一定程度的噪音
#     >> 未經處理的噪音會破壞語音識別應用的準確性
#
# '''

# %% [raw]
# '''
#
# >> 關閉噪音
#     >>  Way off Noise
#         >> 更接近實際的短語
#
#     >> r.adjust_for_ambient_noise(source)
#
# '''

# %%
with jackhammer as source:
    r.adjust_for_ambient_noise(source)
    audio = r.record(source)

r.recognize_google(audio)
# Out:
# 'still smell like old beer drinkers'

# %% [raw]
# '''
#
#     >> adjust_for_ambient_noise()方法
#         >> 讀取文件流的第一秒並將識別器校準到音頻的噪聲水平
#             >>  file stream and calibrates
#         >> 因此，在調用record()捕獲數據之前
#             >> 將消耗該部分流 stream
#
#     >> adjust_for_ambient_noise()
#         >> 使用duration- keyword argument 關鍵字 參數
#             >> 調整用於分析的時間範圍
#         >> 此參數採用以秒為單位的數值，默認設置為1
#             >> 嘗試將此值降低到0.5
#
#
# '''

# %%
with jackhammer as source:
    r.adjust_for_ambient_noise(source, duration=0.5)
    audio = r.record(source)

r.recognize_google(audio)
# Out:
# 'the snail smell of old gear vendors'

# %% [raw]
# '''
#
# >> 嘈雜的文件時，查看實際的API響應會很有幫助
#     >> show_all關鍵字參數設置為
#     >> 來執行此recognize_google()操作True
#
#     >>  noisy files, it can be helpful to see the actual API response. Most APIs return a JSON string containing many possible transcriptions
#     >> recognize_google() 返回一個字典，其中的鍵
#         >> recognize_google() returns a dictionary with the key
#
# '''

# %%
r.recognize_google(audio, show_all=True)
# Out:
# {'alternative': [{'confidence': 0.79366243,
#    'transcript': 'the snail smell of old gear vendors'},
#   {'transcript': 'the snail smelly old gear vendors'},
#   {'transcript': 'the snail smelled old gear vendors'},
#   {'transcript': 'the snail smell old gear vendors'},
#   {'transcript': 'the snails smell of old gear vendors'}],
#  'final': True}

# %% [raw]
# '''
#
# >> 語音識別 - 建立一個 KNN  語音分類器分類
#     >> Building A  Simple KNN - Audio Classification
#
#
# '''

# %% [markdown]
# # 程式範例

# %%
import time
import librosa
from dtw import dtw
import librosa.display
from scipy.spatial.distance import cdist

# %%
ls
# Out:
#  磁碟區 C 中的磁碟是 OS
#  磁碟區序號:  68E3-32FD
#
#  C:\Users\calvi\OneDrive\桌面\課程SpeechRecogination\課程2 的目錄
#
# 2019/09/23  下午 05:51    <DIR>          .
# 2019/09/23  下午 05:51    <DIR>          ..
# 2019/09/23  下午 03:39    <DIR>          .ipynb_checkpoints
# 2019/09/23  下午 05:50    <DIR>          __pycache__
# 2019/09/23  下午 03:59    <DIR>          audio_files
# 2018/09/12  下午 11:09             4,578 dtw.py
# 2019/09/23  下午 05:38    <DIR>          sounds
# 2019/09/23  下午 04:06           661,771 SR02youtubefrontpage.png
# 2019/09/23  下午 04:05           468,943 SR02youtubefrontpage.pptx
# 2019/09/23  下午 03:57    <DIR>          test
# 2019/09/23  下午 03:58    <DIR>          train
# 2019/09/23  下午 05:51         1,566,023 課程 02-  Speech Recognition - Building A  KNN  Audio Classification - 語音識別 - 建立一個 KNN 語音分類器分類.ipynb
#                4 個檔案       2,701,315 位元組
#                8 個目錄  42,956,722,176 位元組可用

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy 
print(numpy.__version__)
# Out:
# 1.14.2

# %%
import IPython.display as ipd

# %%
import librosa

y1, sr1 = librosa.load('./sounds/10.wav')
y2, sr2 = librosa.load('./sounds/78.wav')

# %%
x, sr = librosa.load('./sounds/10.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline

plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y1, sr1)
librosa.display.specshow(mfcc1)

# %% [raw]
# '''
#
# >> 導入 相關 函式庫
#        >> import relative Lib
#
# '''

# %%
import time
import librosa
from dtw import dtw
import librosa.display
from scipy.spatial.distance import cdist

# %%
# Load 加載 - 兩個樣本音頻數據

# %%
y1, sr1 = librosa.load('./train/fcmc0-a1-t.wav')
y2, sr2 = librosa.load('./train/fcmc0-b1-t.wav')

# %%
x, sr = librosa.load('./train/fcmc0-a1-t.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
import matplotlib.pyplot as plt
import librosa.display # 需要有
# %matplotlib inline

plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y1, sr1)
librosa.display.specshow(mfcc1)

# %%
x, sr = librosa.load('./train/fcmc0-b1-t.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
import matplotlib.pyplot as plt
import librosa.display
# %matplotlib inline


plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline

plt.subplot(1, 2, 1)
mfcc1 = librosa.feature.mfcc(y1, sr1)
librosa.display.specshow(mfcc1)

plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y2, sr2)
librosa.display.specshow(mfcc2)

# %%
# Calculate 計算兩個樣本音頻 " a  " 和 " b " 之間的DTW  

dist, cost, path, _ = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
print('Normalized distance between the two sounds:', dist)
# Out:
# Normalized distance between the two sounds: 142.10155503810165

# %%
# 主程式

# %%
import os
dirname = "train"
files = [f for f in os.listdir(dirname) if not f.startswith('.')]

# %%
start = time.clock()
minval = 200
distances = ones((len(files), len(files)))
y = ones(len(files))

for i in range(len(files)):
    y1, sr1 = librosa.load(dirname+"/"+files[i])
    mfcc1 = librosa.feature.mfcc(y1, sr1)
    for j in range(len(files)):
        y2, sr2 = librosa.load(dirname+"/"+files[j])
        mfcc2 = librosa.feature.mfcc(y2, sr2)
        dist, _, _, _ = dtw(mfcc1.T, mfcc2.T, dist=lambda x, y: norm(x - y, ord=1))
#         print files[i],mfcc1.T[0][0],mfcc2.T[0][0],files[j],dist
#         if dist<minval:
#             minval = dist
        distances[i,j] = dist
    if i%2==0:
        y[i] = 0  #'a'
    else:
        y[i] = 1  #'b'
print("Time used: {}s".format(time.clock()-start))
# Out:
# Time used: 21.5674293s

# %%
distances[0] # A dict

# %%
#a = 155.156
#b = 184.702
#c = 158.231
label = ['a','b']

# %%
'''

>> 訓練 kNN分類器 -  確定音頻是 " a " 還是 " b " 

'''

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors=3,metric='euclidean')
classifier.fit(distances, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
'''

>> 測試 樣品  - ' farw0-b1-t.wav ' sound 

'''

# %%
y, sr = librosa.load('./test/farw0-b1-t.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(15, 5))
librosa.display.waveplot(x, sr, alpha=0.8)

# %%
import matplotlib.pyplot as plt
import librosa.display 
# %matplotlib inline


plt.subplot(1, 2, 2)
mfcc2 = librosa.feature.mfcc(y, sr)
librosa.display.specshow(mfcc2)

# %%
y, sr = librosa.load('./test/farw0-b1-t.wav')
mfcc = librosa.feature.mfcc(y, sr)
distanceTest = []
for i in range(len(files)):
    y1, sr1 = librosa.load(dirname+"/"+files[i])
    mfcc1 = librosa.feature.mfcc(y1, sr1)
    dist, _, _, _ = dtw(mfcc.T, mfcc1.T, dist=lambda x, y: norm(x - y, ord=1))
    distanceTest.append(dist)

# %%
dist
# Out:
# 234.82198974731816

# %%
# pre = classifier.predict(distanceTest)[0] # 否 - False
pre = classifier.predict([distanceTest])[0]
print(pre)
# Out:
# 1.0

# %%
label[int(pre)]
# Out:
# 'b'

# %%
print("Predict audio is: '{}'".format(label[int(pre)]))
# Out:
# Predict audio is: 'b'

# %%
y, sr = librosa.load('./test/farw0-b1-t.wav')
ipd.Audio(x, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
